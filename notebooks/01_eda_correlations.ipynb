# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("../data/macro_data.csv").sort_values("date")

# Quick look
display(df.head())
print(df.describe())

# Plot some time series
plt.figure(figsize=(10, 4))
plt.plot(df['date'], df['inflation'], label='Inflation')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# Correlation matrix
feature_cols = ['gdp_growth', 'unemployment', 'interest_rate', '...']
target_col = 'inflation'

corr = df[feature_cols + [target_col]].corr()
plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Correlation matrix")
plt.show()
# Out:
#          date  gdp_growth  inflation  unemployment  interest_rate  \
# 0  2010-01-01         2.1        1.8           6.2            1.0
# 1  2010-04-01         2.3        1.9           6.1            1.0
# 2  2010-07-01         2.0        1.7           6.3            1.1
# 3  2010-10-01         1.8        1.6           6.4            1.1
# 4  2011-01-01         2.4        2.0           6.0            1.2
#
#    consumer_confidence  money_supply
# 0                 92.4         105.2
# 1                 93.1         106.0
# 2                 91.8         106.5
# 3                 90.5         107.1
# 4                 94.0         108.0
#        gdp_growth  inflation  unemployment  interest_rate  \
# count   52.000000  52.000000     52.000000      52.000000
# mean     2.673077   2.550000      5.690385       1.673077
# std      1.529592   0.678667      1.039845       0.741254
# min     -5.000000   0.800000      4.300000       0.200000
# 25%      2.475000   2.075000      4.975000       1.100000
# 50%      3.050000   2.600000      5.600000       1.650000
# 75%      3.400000   3.100000      6.025000       2.300000
# max      4.000000   3.700000      9.500000       2.900000
#
#        consumer_confidence  money_supply
# count            52.000000     52.000000
# mean             95.523077    126.696154
# std              11.806854     13.507891
# min              60.000000    105.200000
# 25%              91.475000    115.300000
# 50%              97.850000    126.400000
# 75%             104.150000    137.400000
# max             111.100000    150.800000
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 23
#      20 feature_cols = ['gdp_growth', 'unemployment', 'interest_rate', '...']
#      21 target_col = 'inflation'
# ---> 23 corr = df[feature_cols + [target_col]].corr()
#      24 plt.figure(figsize=(8, 6))
#      25 sns.heatmap(corr, annot=True, cmap='coolwarm')
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\indexes\base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['...'] not in index"
